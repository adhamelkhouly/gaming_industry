# %% [markdown]
# # A Look at The Gaming Industry (Genres and Releases)
# This notebook will be used for the main part of the project, that is analyzing the data for the genres, the release years, and the scores. For the sales data analysis, please check out A Look at The Gaming Industry (Sales).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
from itertools import chain
from helpers import *
np.random.seed(2019)
# %matplotlib inline

df = pd.read_csv('./ign.csv')


print("Dataset Shape: {}".format(df.shape))
df.head()
# Out:
# Dataset Shape: (18625, 11)
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11

# %%
# Dropping unneccessary columns
df.drop(['score_phrase', 'url'], axis=1, inplace=True)

df.rename(columns={'Unnamed: 0': 'game_id'}, inplace=True)

# Most rows are completely full, therefore I am going with deleting about 40 rows out of 18625
df = df.dropna()

# 1970 happens to only have 1 game, therefore I am not including that row
df = df[df.release_year != 1970]

print("Dataset Shape: {}".format(df.shape))
df.head()
# Out:
# Dataset Shape: (18588, 9)
#    game_id                                              title  \
# 0        0                            LittleBigPlanet PS Vita
# 1        1  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        2                               Splice: Tree of Life
# 3        3                                             NHL 13
# 4        4                                             NHL 13
#
#            platform  score       genre editors_choice  release_year  \
# 0  PlayStation Vita    9.0  Platformer              Y          2012
# 1  PlayStation Vita    9.0  Platformer              Y          2012
# 2              iPad    8.5      Puzzle              N          2012
# 3          Xbox 360    8.5      Sports              N          2012
# 4     PlayStation 3    8.5      Sports              N          2012
#
#    release_month  release_day
# 0              9           12
# 1              9           12
# 2              9           12
# 3              9           11
# 4              9           11

# %% [markdown]
# ### I will start by some basic analysis, to get a feel for the data

# %%
df.describe()
# Out:
#             game_id         score  release_year  release_month   release_day
# count  18588.000000  18588.000000  18588.000000   18588.000000  18588.000000
# mean    9306.783086      6.950769   2006.510598       7.140198     15.602216
# std     5375.899857      1.712087      4.580990       3.476850      8.692034
# min        0.000000      0.500000   1996.000000       1.000000      1.000000
# 25%     4651.750000      6.000000   2003.000000       4.000000      8.000000
# 50%     9298.500000      7.300000   2007.000000       8.000000     16.000000
# 75%    13959.250000      8.200000   2010.000000      10.000000     23.000000
# max    18624.000000     10.000000   2016.000000      12.000000     31.000000

# %%
status_vals = df.release_year.value_counts()  
(status_vals/df.shape[0]).plot(kind="bar");
plt.title("Games Released Per Year Proportions"); # 10% of games are released in 2008

# Strategy, RPG                   6.987013    15.636364
# RPG, Compilation                8.500000    23.250000
# Card, RPG                       6.111111    16.888889
# Music, Editor                   5.833333    11.333333
# Productivity, Action           10.000000     7.000000
# Strategy, Simulation            2.000000    26.000000
# Racing, Shooter                 2.500000     9.500000
# Compilation, RPG                7.000000    14.000000
# Puzzle, Platformer              5.000000     5.000000
# Shooter, Platformer             8.333333     6.333333
# Racing, Simulation              7.280000    15.400000
# Platformer, Action              5.454545    12.545455
# Music, RPG                      9.000000    12.000000
# Adventure, Platformer          11.000000    13.000000
# Platformer, Adventure           5.875000    22.250000
# Music, Adventure                4.000000    21.000000
# Shooter, First-Person           3.000000    10.000000
# Adventure, Episodic             7.000000     2.000000
# Other, Action                   9.000000     8.000000
# Puzzle, RPG                    10.000000    11.000000
# Hardware                        3.500000    19.000000
# Compilation, Compilation       10.000000     9.000000
#
# [112 rows x 5 columns]

# %% [markdown]
# ### Some genres are duplicated. For example there is "Hunting", "Hunting, Action", and "Action". I fix that below.

# %%
new_df = pd.DataFrame(df.genre.str.split(', ').tolist(), index=[df.game_id, df.title, df.platform, df.score,
                                                                  df.editors_choice, df.release_year, 
                                                                  df.release_month, df.release_day]).stack()
new_df = new_df.reset_index([0, 'game_id', 'title', 'editors_choice', 'score', 
                             'release_year', 'release_month', 'release_day', 'platform'])
new_df = new_df.rename(columns={0: 'genre'})

df = new_df
print("Dataset Shape: {}".format(df.shape))
df.head()
# Out:
# Dataset Shape: (21204, 9)
#    game_id                                              title  \
# 0        0                            LittleBigPlanet PS Vita
# 1        1  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        2                               Splice: Tree of Life
# 3        3                                             NHL 13
# 4        4                                             NHL 13
#
#            platform  score editors_choice  release_year  release_month  \
# 0  PlayStation Vita    9.0              Y          2012              9
# 1  PlayStation Vita    9.0              Y          2012              9
# 2              iPad    8.5              N          2012              9
# 3          Xbox 360    8.5              N          2012              9
# 4     PlayStation 3    8.5              N          2012              9
#
#    release_day       genre
# 0           12  Platformer
# 1           12  Platformer
# 2           12      Puzzle
# 3           11      Sports
# 4           11      Sports

# %%
df.groupby("genre").mean().sort_values("score")
# Out:
#                    game_id     score  release_year  release_month  release_day
# genre
# Casino         6601.903226  5.129032   2004.129032       8.193548    16.483871
# Adult         12705.000000  5.400000   2009.333333       6.000000     5.666667
# Golf          18205.000000  5.500000   2015.000000       7.000000    14.000000
# Hunting        7832.408696  5.668696   2004.886957       8.069565    15.269565
# Other          8014.260870  5.678261   2004.782609       7.739130    16.260870
# Party         10195.197183  5.855634   2007.330986       7.514085    14.873239
# Productivity  11362.413043  5.884783   2008.021739       7.500000    15.086957
# Word Game     11130.166667  5.950000   2009.666667       8.000000    10.166667
# Virtual Pet   10584.243902  6.026829   2007.439024       6.646341    15.146341
# Trivia        10332.008264  6.152066   2006.867769       7.834711    16.206612
# Educational   10882.101449  6.265217   2007.710145       7.971014    15.028986
# Pinball        8334.115385  6.537179   2005.410256       6.538462    15.102564
# Card          10357.841808  6.888701   2007.463277       6.587571    16.401130
# Baseball      17672.500000  6.950000   2014.000000       4.000000     8.500000
# Music         11513.341232  6.987441   2008.120853       8.021327    14.926540
# Simulation     9170.383657  6.988089   2006.274238       7.164820    15.440443
# Fighting       8583.879630  6.988426   2005.924383       7.341049    15.717593
# Compilation    9617.564815  6.990278   2006.712963       7.638889    16.388889
# Sports         7730.522217  7.036189   2005.045809       7.271186    15.704535
# Wrestling      7683.029630  7.057778   2004.874074       8.511111    15.192593
# Adventure     10543.337426  7.078978   2007.901768       7.144401    15.581532
# Puzzle        10249.803002  7.090994   2007.294559       6.920263    15.240150
# Shooter       10549.714373  7.143484   2007.775274       7.078563    15.373934
# Platformer     9795.742353  7.218824   2006.895294       7.242353    15.212941
# Strategy       8858.013901  7.287576   2006.063423       6.801911    15.388358
# RPG           10595.866158  7.566782   2007.879334       6.797503    15.890430
# Episodic      17065.500000  8.900000   2013.000000       7.000000     2.000000
# First-Person  17611.000000  8.900000   2014.000000       3.000000    10.000000

# %% [markdown]
# ### Now let us take a look at general correlations

# %%
df.hist();

# %%
sns.heatmap(df.corr(), annot=True, fmt=".2f"); # Note that this does not include categorical data

# We can see a slight correlation between release dates and the score. This we will invistigate more.

# %% [markdown]
# ### Let us now build the model, and take care of categorical data by adding dummy columns

# %%
# The functions can be found in the file helpers.py
X, y = clean_data(df)

test_score, train_score, lm_model, X_train, X_test, y_train, y_test = build_linear_mod(X, y)

# %%
coef_df = coef_weights(lm_model, X_train)

#A quick look at the top results
coef_df.head(20)
# Out:
#                          Feature  Coefficient  Abs_Coefficient
# 11        platform_Dreamcast VMU    -1.848682         1.848682
# 3               editors_choice_Y     1.142428         1.142428
# 73                genre_Episodic     0.988193         0.988193
# 15             platform_Game.Com    -0.971414         0.971414
# 70                  genre_Casino    -0.886233         0.886233
# 77                    genre_Golf    -0.796078         0.796078
# 80                   genre_Other    -0.786420         0.786420
# 7            platform_Atari 5200     0.658336         0.658336
# 64                   genre_Adult    -0.657432         0.657432
# 12             platform_Game Boy     0.645735         0.645735
# 66                genre_Baseball     0.634626         0.634626
# 55           platform_WonderSwan    -0.602025         0.602025
# 49            platform_Web Games     0.589188         0.589188
# 32                 platform_Ouya     0.555924         0.555924
# 44              platform_SteamOS     0.534923         0.534923
# 25  platform_NeoGeo Pocket Color     0.534071         0.534071
# 81                   genre_Party    -0.522555         0.522555
# 84            genre_Productivity    -0.501559         0.501559
# 5                platform_Arcade    -0.499100         0.499100
# 78                 genre_Hunting    -0.497104         0.497104

# %% [markdown]
# ### It can be seen that some old consoles have the strongest coefficients. That led me to believe there were less games in the dataset for these consoles, which also happen to be given a high score.

# %%
df.platform.value_counts()  # This confirmed my observation
# Out:
# PC                      3776
# PlayStation 2           2041
# Xbox 360                1887
# PlayStation 3           1567
# Wii                     1559
# Nintendo DS             1185
# PlayStation             1012
# Xbox                     984
# Wireless                 960
# iPhone                   920
# PlayStation Portable     749
# Game Boy Advance         717
# GameCube                 632
# Game Boy Color           374
# Nintendo 64              326
# PlayStation 4            319
# Dreamcast                317
# Nintendo DSi             274
# Nintendo 3DS             257
# Xbox One                 249
# PlayStation Vita         183
# Wii U                    136
# iPad                     110
# Macintosh                 91
# Lynx                      88
# Genesis                   61
# NES                       50
# TurboGrafx-16             46
# Android                   43
# Super NES                 38
# N-Gage                    37
# NeoGeo Pocket Color       33
# Game Boy                  23
# iPod                      18
# Sega 32X                  16
# Windows Phone             14
# Master System             13
# Arcade                    12
# Linux                     11
# NeoGeo                    10
# Nintendo 64DD              7
# Commodore 64/128           6
# Saturn                     6
# Atari 2600                 5
# WonderSwan                 4
# Game.Com                   4
# TurboGrafx-CD              3
# Atari 5200                 2
# Vectrex                    2
# New Nintendo 3DS           2
# Web Games                  2
# Ouya                       1
# Sega CD                    1
# Dreamcast VMU              1
# Pocket PC                  1
# WonderSwan Color           1
# Windows Surface            1
# SteamOS                    1
# DVD / HD Video Game        1
# Name: platform, dtype: int64

# %%
# I decided to therefore delete genres and platforms with less than 100 entries
vc = df.platform.value_counts()
platforms = vc[vc > 100].index.to_list()
df = df[df.platform.isin(platforms)]

vc = df.genre.value_counts()
genres = vc[vc > 100].index.to_list()
df = df[df.genre.isin(genres)]


df.shape
# Out:
# (20116, 9)

# %%
# The functions can be found in the file helpers.py
X, y = clean_data(df)

test_score, train_score, lm_model, X_train, X_test, y_train, y_test = build_linear_mod(X, y)
coef_df = coef_weights(lm_model, X_train)

coef_df[:10] # Biggest indicator is the editor's choice, which makes lots of sense
# Out:
#                    Feature  Coefficient  Abs_Coefficient
# 3         editors_choice_Y     1.138738         1.138738
# 34           genre_Hunting    -0.568857         0.568857
# 36             genre_Party    -0.362230         0.362230
# 20          platform_Wii U     0.345069         0.345069
# 45            genre_Trivia    -0.340274         0.340274
# 19            platform_Wii    -0.324654         0.324654
# 16  platform_PlayStation 4     0.317703         0.317703
# 10    platform_Nintendo DS    -0.267718         0.267718
# 24       platform_Xbox One     0.261730         0.261730
# 11   platform_Nintendo DSi    -0.260167         0.260167

# %% [markdown]
# # Now let us attempt to answer our busniess questions

# %% [markdown]
# ## 1. What are the main factors affecting a game's score?

# %%
q1_df = coef_df.set_index('Feature')
q1_df.drop('Abs_Coefficient', axis=1).sort_values(
    'Coefficient', ascending=False).head(11).plot(kind='barh', figsize=(10,5));

# %%
q2_df = coef_df.set_index('Feature')
q2_df.drop('Abs_Coefficient', axis=1).sort_values(
    'Coefficient', ascending=True).head(20).plot(kind='barh', figsize=(7,7));

# %% [markdown]
# From the above plots, it can be seen that the Editor's choice is the strongest indicator of a high score game. While the genre of Party and Hunting seem to be usually rated a lot lower than other genres. The RPG genre (a personal favourite of mine!) has the biggest positive impact on a game's score.

# %% [markdown]
# ## 2. Do game release dates affect how a game is received?

# %% [markdown]
# Turns out that is not the case. From the above graph, we can see that release_month and release_day have relatively weights, and therefore do not have a significant impact on a game's score. However, the dataset used for this report did not include game sales, and I suspect it has a lot to do with game sales!
